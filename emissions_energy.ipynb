# %%
import pandas as pd

df = pd.read_csv("data/processed/global_panel.csv")

# %%
latest_year = df['year'] = 2022
df_latest = df[df['year'] == latest_year]


cluster_vars = [
    'co2_per_capita',
    'renewables_share_energy',
    'fossil_share_energy',
    'low_carbon_share_energy',
    'gdp'
]

df_cluster = df_latest[['country'] + cluster_vars].dropna()
df_cluster.set_index('country', inplace=True)
df_cluster.head()
# Out:
#          co2_per_capita  renewables_share_energy  fossil_share_energy  \
# country
# Algeria           0.533                    4.487               95.513
# Algeria           0.669                    3.313               96.687
# Algeria           0.655                    4.042               95.958
# Algeria           0.687                    5.171               94.829
# Algeria           0.836                    2.996               97.004
#
#          low_carbon_share_energy           gdp
# country
# Algeria                    4.487  3.566197e+10
# Algeria                    3.313  3.393263e+10
# Algeria                    4.042  3.709477e+10
# Algeria                    5.171  4.142389e+10
# Algeria                    2.996  4.538746e+10

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_cluster)

# %%
from sklearn.cluster import KMeans

k = 4
kmeans = KMeans(n_clusters=k, random_state=42)


clusters = kmeans.fit_predict(X_scaled)


df_cluster['cluster'] = clusters
df_cluster.head()
# Out:
#          co2_per_capita  renewables_share_energy  fossil_share_energy  \
# country
# Algeria           0.533                    4.487               95.513
# Algeria           0.669                    3.313               96.687
# Algeria           0.655                    4.042               95.958
# Algeria           0.687                    5.171               94.829
# Algeria           0.836                    2.996               97.004
#
#          low_carbon_share_energy           gdp  cluster
# country
# Algeria                    4.487  3.566197e+10        0
# Algeria                    3.313  3.393263e+10        0
# Algeria                    4.042  3.709477e+10        0
# Algeria                    5.171  4.142389e+10        0
# Algeria                    2.996  4.538746e+10        0

# %%
print(df_cluster.columns)
# Out:
# Index(['co2_per_capita', 'renewables_share_energy', 'fossil_share_energy',
#        'low_carbon_share_energy', 'gdp', 'cluster'],
#       dtype='object')

# %%
df_cluster.reset_index(inplace=True)
df_cluster.rename(columns={'index': 'country'}, inplace=True)

# %%
import plotly.express as px


df_cluster['cluster_label'] = df_cluster['cluster'].map({
    3: "High CO₂, Fossil-heavy",
    2: "Moderate CO₂, Balanced Energy",
    0: "Moderate CO₂, Fossil-heavy",
    1: "Low CO₂, Renewable-heavy"
})

fig = px.scatter(
    df_cluster,
    x='co2_per_capita',
    y='renewables_share_energy',
    size='fossil_share_energy',
    color='cluster_label',
    hover_name='country',
    hover_data={
        'co2_per_capita': True,
        'renewables_share_energy': True,
        'fossil_share_energy': True,
        'low_carbon_share_energy': True,
        'gdp': True,
        'cluster_label': False
    },
    title=f"Country Clusters by CO₂ & Energy Profile ({latest_year})",
    size_max=60
)

fig.update_layout(
    xaxis_title="CO₂ per Capita",
    yaxis_title="Renewables Share (%)",
    legend_title="Cluster",
    template="plotly_white"
)

fig.show()
